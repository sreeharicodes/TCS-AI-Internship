# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df1 =pd.read_csv('ign.csv')

# %%
df1
# Out:
#           id                                                url  \
# 0          0             /games/littlebigplanet-vita/vita-98907
# 1          1  /games/littlebigplanet-ps-vita-marvel-super-he...
# 2          2                          /games/splice/ipad-141070
# 3          3                      /games/nhl-13/xbox-360-128182
# 4          4                           /games/nhl-13/ps3-128181
# 5          5         /games/total-war-battles-shogun/mac-142565
# 6          6          /games/double-dragon-neon/xbox-360-131320
# 7          7                      /games/guild-wars-2/pc-896298
# 8          8               /games/double-dragon-neon/ps3-131321
# 9          9          /games/total-war-battles-shogun/pc-142564
# 10        10          /games/tekken-tag-tournament-2/ps3-124584
# 11        11     /games/tekken-tag-tournament-2/xbox-360-124581
# 12        12                    /games/wild-blood/iphone-139363
# 13        13    /games/mark-of-the-ninja-135615/xbox-360-129276
# ...

# %%
df2 = pd.read_csv('ign_score.csv')

# %%
df2
# Out:
#           id score_phrase                                              title  \
# 0          0      Amazing                            LittleBigPlanet PS Vita
# 1          1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2          2        Great                               Splice: Tree of Life
# 3          3        Great                                             NHL 13
# 4          4        Great                                             NHL 13
# 5          5         Good                          Total War Battles: Shogun
# 6          6        Awful                                Double Dragon: Neon
# 7          7      Amazing                                       Guild Wars 2
# 8          8        Awful                                Double Dragon: Neon
# 9          9         Good                          Total War Battles: Shogun
# 10        10         Good                            Tekken Tag Tournament 2
# ...

# %%
df = pd.merge(df1,df2, on='id')

# %%
df
# Out:
#           id                                                url  \
# 0          0             /games/littlebigplanet-vita/vita-98907
# 1          1  /games/littlebigplanet-ps-vita-marvel-super-he...
# 2          2                          /games/splice/ipad-141070
# 3          3                      /games/nhl-13/xbox-360-128182
# 4          4                           /games/nhl-13/ps3-128181
# 5          5         /games/total-war-battles-shogun/mac-142565
# 6          6          /games/double-dragon-neon/xbox-360-131320
# 7          7                      /games/guild-wars-2/pc-896298
# 8          8               /games/double-dragon-neon/ps3-131321
# 9          9          /games/total-war-battles-shogun/pc-142564
# 10        10          /games/tekken-tag-tournament-2/ps3-124584
# 11        11     /games/tekken-tag-tournament-2/xbox-360-124581
# 12        12                    /games/wild-blood/iphone-139363
# 13        13    /games/mark-of-the-ninja-135615/xbox-360-129276
# ...

# %%
top = df.sort_values(by='score',ascending=False)

# %%
top=top[:10]

# %%
top['title']
# Out:
# 18365                                               Steins
# 6749                                           Jade Empire
# 2649                    The Legend of Zelda: Majora's Mask
# 3046                                  Conker's Bad Fur Day
# 2666                              Tony Hawk's Pro Skater 2
# 6339                         Grand Theft Auto: San Andreas
# 3340                                          Advance Wars
# 17161               The Legend of Zelda: The Wind Waker HD
# 17162    The Legend of Zelda: The Wind Waker HD (Ninten...
# 866                                       Metal Gear Solid
# Name: title, dtype: object

# %%
df.iloc[18365,11] = '7.0'

# %%
df['score']=df['score'].astype(float)

# %%
rank = df.groupby('title').score.mean().sort_values(ascending=False)

# %%
rank
# Out:
# title
# Mario Golf [Game Boy Color]                                   10.0
# The Last of Us                                                10.0
# Pokemon Silver Version                                        10.0
# Checkered Flag                                                10.0
# Infinity Blade II                                             10.0
# Undertale                                                     10.0
# Pokemon Blue Version                                          10.0
# Inside                                                        10.0
# Shanghai                                                      10.0
# Pac-Man Championship Edition DX                               10.0
# Pokemon Red Version                                           10.0
# The Last of Us: Remastered                                    10.0
# Metal Gear Solid V: The Phantom Pain                          10.0
# The Witness                                                   10.0
# ...

# %%
#Plot movie scores across each genre.
import seaborn as sns
dfg = pd.merge(df1,df2, on='id')
sns.distplot(dfg['genre'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-ae9e9436ec50> in <module>()
#       2 import seaborn as sns
#       3 dfg = pd.merge(df1,df2, on='id')
# ----> 4 sns.distplot(dfg['genre'])
#
# /usr/local/lib/python3.6/site-packages/seaborn/distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     193             line, = ax.plot(0, a.mean())
#     194         else:
# --> 195             line, = ax.plot(a.mean(), 0)
#     196         color = line.get_color()
#     197         line.remove()
#
# /usr/local/lib/python3.6/site-packages/numpy/core/_methods.py in _mean(a, axis, dtype, out, keepdims)
#      68             is_float16_result = True
#      69
# ---> 70     ret = umr_sum(arr, axis, dtype, out, keepdims)
#      71     if isinstance(ret, mu.ndarray):
# ...

# %%
df=df.loc[:, ~df.columns.str.contains('^Unnamed')]

# %%
sns.distplot(df['genre'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-69e3da3caa4c> in <module>()
# ----> 1 sns.distplot(df['genre'])
#
# /usr/local/lib/python3.6/site-packages/seaborn/distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     193             line, = ax.plot(0, a.mean())
#     194         else:
# --> 195             line, = ax.plot(a.mean(), 0)
#     196         color = line.get_color()
#     197         line.remove()
#
# /usr/local/lib/python3.6/site-packages/numpy/core/_methods.py in _mean(a, axis, dtype, out, keepdims)
#      68             is_float16_result = True
#      69
# ---> 70     ret = umr_sum(arr, axis, dtype, out, keepdims)
#      71     if isinstance(ret, mu.ndarray):
#      72         ret = um.true_divide(
#
# TypeError: must be str, not float

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18625 entries, 0 to 18624
# Data columns (total 11 columns):
# id                18625 non-null int64
# url               18625 non-null object
# genre             18589 non-null object
# editors_choice    18625 non-null object
# release_year      18625 non-null object
# release_month     18625 non-null int64
# release_day       18625 non-null int64
# score_phrase      18625 non-null object
# title             18625 non-null object
# platform          18625 non-null object
# score             18625 non-null float64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 2.3+ MB

# %%
sns.distplot(df['genre'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-69e3da3caa4c> in <module>()
# ----> 1 sns.distplot(df['genre'])
#
# /usr/local/lib/python3.6/site-packages/seaborn/distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     193             line, = ax.plot(0, a.mean())
#     194         else:
# --> 195             line, = ax.plot(a.mean(), 0)
#     196         color = line.get_color()
#     197         line.remove()
#
# /usr/local/lib/python3.6/site-packages/numpy/core/_methods.py in _mean(a, axis, dtype, out, keepdims)
#      68             is_float16_result = True
#      69
# ---> 70     ret = umr_sum(arr, axis, dtype, out, keepdims)
#      71     if isinstance(ret, mu.ndarray):
#      72         ret = um.true_divide(
#
# TypeError: must be str, not float

# %%
df['score']=df['score'].astype(str)
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18625 entries, 0 to 18624
# Data columns (total 11 columns):
# id                18625 non-null int64
# url               18625 non-null object
# genre             18589 non-null object
# editors_choice    18625 non-null object
# release_year      18625 non-null object
# release_month     18625 non-null int64
# release_day       18625 non-null int64
# score_phrase      18625 non-null object
# title             18625 non-null object
# platform          18625 non-null object
# score             18625 non-null object
# dtypes: int64(3), object(8)
# memory usage: 2.3+ MB

# %%
sns.distplot(df['genre'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-69e3da3caa4c> in <module>()
# ----> 1 sns.distplot(df['genre'])
#
# /usr/local/lib/python3.6/site-packages/seaborn/distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     193             line, = ax.plot(0, a.mean())
#     194         else:
# --> 195             line, = ax.plot(a.mean(), 0)
#     196         color = line.get_color()
#     197         line.remove()
#
# /usr/local/lib/python3.6/site-packages/numpy/core/_methods.py in _mean(a, axis, dtype, out, keepdims)
#      68             is_float16_result = True
#      69
# ---> 70     ret = umr_sum(arr, axis, dtype, out, keepdims)
#      71     if isinstance(ret, mu.ndarray):
#      72         ret = um.true_divide(
#
# TypeError: must be str, not float
